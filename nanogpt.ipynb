# %%
import math

-math.log(1/168)
# Out:
# 5.123963979403259

# %%
data_path = "/mnt/c/svn/ng-video-lecture/data/" 
# !ls {data_path}
# !gzip -d {data_path}NPlus1.tar.gz
# !tar -xf {data_path}NPlus1.tar {data_path}
# Out:
# NPlus1.tar.gz

# %%
import glob
txt_files = glob.glob(f'{data_path}home/tsha/NPlus1/texts/*.txt')

# %%
alphabet = set()
text_len = 0
text = ''
for file in txt_files:
    with open(file, 'r') as f:
        print(file)
        s = ' '.join(f.readlines())
        text += s
        text_len += len(s)
        alphabet.union(set(s))
# Out:
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150302bionics.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150302chaotic.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150302culture.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150302ebola.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150302epigenom.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150302full.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150302gene.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150302goats.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150302hair.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150302lens.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150302longest.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150302mensdd.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150302mouse.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150302neuro.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150302psychostat.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150302rna.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150302spacephoto.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150302voice.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150302zombie.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150318exoplanets.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150318mudskippers.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150318roman-fort.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150318string-theory.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150318taxi-uber.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150318tyres.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150318windows10.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150319bacteria-spectra.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150319e-ink-shoes.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150319greatbritain.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150319spiders.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150320bioluminescence.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150320ch5.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150320cubesats.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150320DNAtest.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150320drone.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150320nitrogen.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150320silica.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150320willow.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150321once-upon-a-time.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150322asteroids.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150323diamonds.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150323peanuts.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150324tournaments.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150327chlamydomonas.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150406almaturaman.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150406blackholes.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150406gender-and-morality-.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150406meniscus.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150406nowayoxide.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150406onedollarcancertest.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150406rydberg.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150407acoustic-sampler.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150407art-colour-through-history.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150407bacteria-tornadoes.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150407black-book.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150407crime-fighter.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150407npoly.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150407robot-fish.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150407sponges.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150407weatherwindows.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150408airship.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150408automatons.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150408drones.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150408flir.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150408httpwwwnaturecomncomms2015150310ncomms742.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150408intel-camera.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150408meteor.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150408scythian-treasure.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150408tunneling.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150408vikings.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150408wrinkles.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150408yandex.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150409elephant.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150409European-farmers.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150409lawrencium.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150409machine-learning.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150409mummies.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150409nano-self-destruct.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150409police-drones.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150409spooning-skeletons.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150409the-moon.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150409tyrannosaur.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150409young-star.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150410babystarboom.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150410CUORE.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150410enzymes.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150410hawaiian-treasure.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150410insurance-drones.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150410korean-fossils.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150410mini-augmented-vision.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150410Shakespeares-signature.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150410terror-bird.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150410wasabi.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150413dinosaurs.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150413earthquake.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150413gas-flow.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150413greek-epos.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150413holograms-unite.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150413hylobates-lar.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150413meteorite.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150413neuroflowers.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150414anorexicmice.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150414cancer-phone.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150414cardiomyocitereg.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150414dark-matter.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150414drone-wars.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150414hawking.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150414lima-inca.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150414sea-people.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150414space-donut.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150414spanish-gominins.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150415abbey-google.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150415broken-bones.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150415drone-swarm.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150415Macchiarini-trial.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150415mask.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150415pharaon-chapel.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150415puzzle.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150415rosetta.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150415whale-record.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150416Aerial-Information-Platform.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150416amsantiprotons.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150416comparative-study-of-Rembrandt.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150416dust.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150416infinite-recording.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150416kenian-ancient-tools.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150416micemoms.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150416nanotube-sensor.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150416perovskites.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150416quantmusic.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150416space-glitter.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20150416stabexplosives.txt
# /mnt/c/svn/ng-video-lecture/data/home/tsha/NPlus1/texts/20
#  Международная группа исследователей установила, что извержения на сатурнианском спутнике Энцеладе происходят не отдельными джетами, а в виде своего рода «занавесок» вдоль разломов (известных как «тигровые полосы»). Статья ученых появилась в журнале Nature, а ее краткое изложение приводится на сайте Лаборатории реактивного движения NASA.Геологическая активность Энцелада была обнаружена зондом «Кассини» в 2005 году. Было установлено, что в окрестности южного полюса имеется ряд разломов, из которых в космическое пространство выбрасываются потоки жидкой воды (она играет роль лав

# %%
# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
print(''.join(chars))
print(vocab_size)
# Out:
#
#  !"#$%&'()*+,-./0123456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ[\]^_abcdefghijklmnopqrstuvwxyz{|}~ «­®°±²³·º»Ö×ØÚßàáãäåæçéêëíñòóôöøúüćčěıłōőŞşŠũżș˚́ΔΘΛΞΣΦάήαβγδεηθκλμνοπρςστφχψόώЁАБВГДЕЖЗИЙКЛМНОПРСТУФХЦЧШЩЫЬЭЮЯабвгдежзийклмнопрстуфхцчшщъыьэюяёіѝầἀἠ   –—’“”„•… ₁₅№→∈−√∼≈≠≤⋅─☉影无鞋﻿💕
# 279

# %%
def clean_text(text):
    ret = ''
    allowed_symbols = " !\"#$%&'()*+,-./0123456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ[\]^_abcdefghijklmnopqrstuvwxyz{|}~«»ЁАБВГДЕЖЗИЙКЛМНОПРСТУФХЦЧШЩЫЬЭЮЯабвгдежзийклмнопрстуфхцчшщъыьэюяёі№"
    for w in text:
        if w in allowed_symbols:
            ret+=w
    return ret

text = clean_text(text)

# %%
# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
print(''.join(chars))
print(vocab_size)
# Out:
#  !"#$%&'()*+,-./0123456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ[\]^_abcdefghijklmnopqrstuvwxyz{|}~«»ЁАБВГДЕЖЗИЙКЛМНОПРСТУФХЦЧШЩЫЬЭЮЯабвгдежзийклмнопрстуфхцчшщъыьэюяёі№
# 163

# %%
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

code_str = 'в окрестности южного полюса имеется ряд разломов,'

print(encode(code_str))
print(decode(encode(code_str)))
# Out:
# [130, 0, 142, 138, 144, 133, 145, 146, 141, 142, 145, 146, 136, 0, 158, 134, 141, 142, 131, 142, 0, 143, 142, 139, 158, 145, 128, 0, 136, 140, 133, 133, 146, 145, 159, 0, 144, 159, 132, 0, 144, 128, 135, 139, 142, 140, 142, 130, 12]
# в окрестности южного полюса имеется ряд разломов,

# %%
# let's now encode the entire text dataset and store it into a torch.Tensor
import torch # we use PyTorch: https://pytorch.org
data = torch.tensor(encode(text), dtype=torch.long)
print(data.shape, data.dtype)
print(data[:1000]) # the 1000 characters we looked at earier will to the GPT look like this
# Out:
# torch.Size([14266844]) torch.int64
# tensor([  0, 114, 142, 146, 144, 147, 132, 141, 136, 138, 136,   0,  99, 133,
#         141, 145, 138, 142, 131, 142,   0, 140, 133, 132, 136, 150, 136, 141,
#         145, 138, 142, 131, 142,   0, 147, 141, 136, 130, 133, 144, 145, 136,
#         146, 133, 146, 128,   0, 144, 128, 135, 144, 128, 129, 142, 146, 128,
# Let's now split up the data into train and validation sets
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# %%
block_size = 8
train_data[:block_size+1]
# Out:
# tensor([  0, 114, 142, 146, 144, 147, 132, 141, 136])

# %%
x = train_data[:block_size]
y = train_data[1:block_size+1]
for t in range(block_size):
    context = x[:t+1]
    target = y[t]
    print(f"when input is {context} the target: {target}")
# Out:
# when input is tensor([0]) the target: 114
# when input is tensor([  0, 114]) the target: 142
# when input is tensor([  0, 114, 142]) the target: 146
# when input is tensor([  0, 114, 142, 146]) the target: 144
# when input is tensor([  0, 114, 142, 146, 144]) the target: 147
# when input is tensor([  0, 114, 142, 146, 144, 147]) the target: 132
# when input is tensor([  0, 114, 142, 146, 144, 147, 132]) the target: 141
# when input is tensor([  0, 114, 142, 146, 144, 147, 132, 141]) the target: 136

# %%
torch.manual_seed(1337)
batch_size = 4 # how many independent sequences will we process in parallel?
block_size = 8 # what is the maximum context length for predictions?

def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    return x, y

xb, yb = get_batch('train')
print('inputs:')
print(xb.shape)
print(xb)
print('targets:')
print(yb.shape)
print(yb)

print('----')

for b in range(batch_size): # batch dimension
    for t in range(block_size): # time dimension
        context = xb[b, :t+1]
        target = yb[b,t]
        print(f"when input is {context.tolist()} the target: {target}")
# Out:
# inputs:
# torch.Size([4, 8])
# tensor([[141, 136, 159,   0,  44,  72,  75,  72],
#         [142, 130, 133, 138,   0, 145,   0, 143],
#         [130,   0, 143, 142, 136, 145, 138, 128],
#         [151, 136, 146, 156,   0, 130,   0, 136]])
# targets:
# torch.Size([4, 8])
# tensor([[136, 159,   0,  44,  72,  75,  72,  84],
#         [130, 133, 138,   0, 145,   0, 143, 144],
#         [  0, 143, 142, 136, 145, 138, 128, 149],
#         [136, 146, 156,   0, 130,   0, 136, 146]])
# ----
# when input is [141] the target: 136
# when input is [141, 136] the target: 159
# when input is [141, 136, 159] the target: 0
# when input is [141, 136, 159, 0] the target: 44
# when input is [141, 136, 159, 0, 44] the target: 72
# when input is [141, 136, 159, 0, 44, 72] the target: 75
# when input is [141, 136, 159, 0, 44, 72, 75] the target: 72
# when input is [141, 136, 159, 0, 44, 72, 75, 72] the target: 84
# when input is [142] the target: 130
# when input is [142, 130] the target: 133
# when input is [142, 130, 133] the target: 138
# when input is [142, 130, 133, 138] the target: 0
# when input is [142, 130, 133, 138, 0] the target: 145
# when input is [142, 130, 133, 138, 0, 145] the target: 0
# when input is [142, 130, 133, 138, 0, 145, 0] the target: 143
# when input is [142, 130, 133, 138, 0, 145, 0, 143] the target: 144
# when input is [130] the target: 0
# when input is [130, 0] the target: 143
# when input is [130, 0, 143] the target: 142
# when input is [130, 0, 143, 142] the target: 136
# when input is [130, 0, 143, 142, 136] the target: 145
# when input is [130, 0, 143, 142, 136, 145] the target: 138
# when input is [130, 0, 143, 142, 136, 145, 138] the target: 128
# when input is [130, 0, 143, 142, 136, 145, 138, 128] the target: 149
# when input is [151] the target: 136
# when input is [151, 136] the target: 146
# when input is [151, 136, 146] the target: 156
# when input is [151, 136, 146, 156] the target: 0
# when input is [151, 136, 146, 156, 0] the target: 130
# when input is [151, 136, 146, 156, 0, 130] the target: 0
# when input is [151, 136, 146, 156, 0, 130, 0] the target: 136
# when input is [151, 136, 146, 156, 0, 130, 0, 136] the target: 146

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F
torch.manual_seed(1337)

class BigramLanguageModel(nn.Module):

    def __init__(self, vocab_size):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, vocab_size)

    def forward(self, idx, targets=None):

        # idx and targets are both (B,T) tensor of integers
        logits = self.token_embedding_table(idx) # (B,T,C)
        
        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss
    
    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # get the predictions
            logits, loss = self(idx)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

m = BigramLanguageModel(vocab_size)
logits, loss = m(xb, yb)
print(logits.shape)
print(loss)

print(decode(m.generate(idx = torch.zeros((1, 1), dtype=torch.long), max_new_tokens=100)[0].tolist()))
# Out:
# torch.Size([32, 163])
# tensor(5.2262, grad_fn=<NllLossBackward0>)
#  рpw3pPh5ПНЕКrVіЮК=гХцёP+9ъВшСН|0МGJЯ+)sЧARЮ\ьылIафdтП'эатб|Y9dЫис"Сb{<=_|j+,MЩ}Щю!Ю&б6еtыО"«#с.9Хыcр

# %%
# create a PyTorch optimizer
optimizer = torch.optim.AdamW(m.parameters(), lr=1e-3)

# %%
batch_size = 32
for steps in range(10000): # increase number of steps for good results... 
    
    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = m(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

print(loss.item())
# Out:
# 2.6404311656951904

# %%
print(decode(m.generate(idx = torch.zeros((1, 1), dtype=torch.long), max_new_tokens=500)[0].tolist()))
# Out:
#  вычамалисе оволпитолленользьзазметежилимо, Еве чите уп патв влиспованы Юнся  ружнотитолий ивы по сое этр, доль рннугрь Brteне у огощиящииеся. удетрни, ей экию Миорузо реноруенос поилерукозотрерыве ФТет пониик рого вомоффо пе исиция  ссцерое гогодлифа при гослая ктана лимелонелотиеникобоерисенаныхпознапове кодребаем сповсаенероженеку. фа, олиечтьшокораллилеля эти тедов во прта скук ииетнив аютодк пригечьслиание иму, в ся пску поторей 10-65искиаютрозастемавтетьнатетголеназдя рсизазавя га ШАлныекал

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

# hyperparameters
batch_size = 128 # how many independent sequences will we process in parallel?
block_size = 64 # what is the maximum context length for predictions?
max_iters = 50000
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.1
# ------------

torch.manual_seed(1337)

# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.224419 M parameters
# step 0: train loss 5.2962, val loss 5.2945
# step 100: train loss 2.9123, val loss 2.8849
# step 200: train loss 2.7023, val loss 2.6849
# step 300: train loss 2.6339, val loss 2.6182
# step 400: train loss 2.5490, val loss 2.5329
# step 500: train loss 2.4514, val loss 2.4354
# step 600: train loss 2.3591, val loss 2.3395
# step 700: train loss 2.2791, val loss 2.2629
# step 800: train loss 2.2112, val loss 2.1890
# step 900: train loss 2.1503, val loss 2.1299
# step 1000: train loss 2.0983, val loss 2.0841
# step 1100: train loss 2.0541, val loss 2.0376
# step 1200: train loss 2.0165, val loss 2.0033
# step 1300: train loss 1.9824, val loss 1.9689
# step 1400: train loss 1.9541, val loss 1.9385
# step 1500: train loss 1.9271, val loss 1.9155
# step 1600: train loss 1.9071, val loss 1.8954
# step 1700: train loss 1.8852, val loss 1.8665
# step 1800: train loss 1.8615, val loss 1.8481
# step 1900: train loss 1.8471, val loss 1.8366
# step 2000: train loss 1.8311, val loss 1.8224
# step 2100: train loss 1.8204, val loss 1.8096
# step 2200: train loss 1.8083, val loss 1.8005
# step 2300: train loss 1.7965, val loss 1.7894
# step 2400: train loss 1.7861, val loss 1.7764
# step 2500: train loss 1.7747, val loss 1.7645
# step 2600: train loss 1.7630, val loss 1.7525
# step 2700: train loss 1.7552, val loss 1.7478
# step 2800: train loss 1.7478, val loss 1.7401
# step 2900: train loss 1.7407, val loss 1.7313
# step 3000: train loss 1.7423, val loss 1.7328
# step 3100: train loss 1.7240, val loss 1.7191
# step 3200: train loss 1.7176, val loss 1.7113
# step 3300: train loss 1.7110, val loss 1.7057
# step 3400: train loss 1.7085, val loss 1.6988
# step 3500: train loss 1.7044, val loss 1.6936
# step 3600: train loss 1.6945, val loss 1.6906
# step 3700: train loss 1.6912, val loss 1.6812
# step 3800: train loss 1.6868, val loss 1.6778
# step 3900: train loss 1.6819, val loss 1.6749
# step 4000: train loss 1.6769, val loss 1.6733
# step 4100: train loss 1.6718, val loss 1.6634
# step 4200: train loss 1.6729, val loss 1.6645
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Admin\Desktop\Courses\kaggle\nanogpt.ipynb Ячейка 19 in <module>
#     <a href='vscode-notebook-cell:/c%3A/Users/Admin/Desktop/Courses/kaggle/nanogpt.ipynb#X22sZmlsZQ%3D%3D?line=201'>202</a>     optimizer.zero_grad(set_to_none=True)
#     <a href='vscode-notebook-cell:/c%3A/Users/Admin/Desktop/Courses/kaggle/nanogpt.ipynb#X22sZmlsZQ%3D%3D?line=202'>203</a>     loss.backward()
# --> <a href='vscode-notebook-cell:/c%3A/Users/Admin/Desktop/Courses/kaggle/nanogpt.ipynb#X22sZmlsZQ%3D%3D?line=203'>204</a>     optimizer.step()
#     <a href='vscode-notebook-cell:/c%3A/Users/Admin/Desktop/Courses/kaggle/nanogpt.ipynb#X22sZmlsZQ%3D%3D?line=205'>206</a> # generate from the model
#     <a href='vscode-notebook-cell:/c%3A/Users/Admin/Desktop/Courses/kaggle/nanogpt.ipynb#X22sZmlsZQ%3D%3D?line=206'>207</a> context = torch.zeros((1, 1), dtype=torch.long, device=device)
#
# File ~/.local/lib/python3.8/site-packages/torch/optim/optimizer.py:88, in Optimizer._hook_for_profile.<locals>.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#      86 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      87 with torch.autograd.profiler.record_function(profile_name):
# ---> 88     return func(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/torch/autograd/grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/torch/optim/adamw.py:145, in AdamW.step(self, closure)
#     142         # record the step after step update
#     143         state_steps.append(state['step'])
# --> 145     F.adamw(params_with_grad,
#     146             grads,
#     147             exp_avgs,
#     148             exp_avg_sqs,
#     149             max_exp_avg_sqs,
#     150             state_steps,
#     151             amsgrad=amsgrad,
#     152             beta1=beta1,
#     153             beta2=beta2,
#     154             lr=group['lr'],
#     155             weight_decay=group['weight_decay'],
#     156             eps=group['eps'],
#     157             maximize=group['maximize'])
#     159 return loss
#
# File ~/.local/lib/python3.8/site-packages/torch/optim/_functional.py:144, in adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     142 # Decay the first and second moment running average coefficient
#     143 exp_avg.mul_(beta1).add_(grad, alpha=1 - beta1)
# --> 144 exp_avg_sq.mul_(beta2).addcmul_(grad, grad, value=1 - beta2)
#     145 if amsgrad:
#     146     # Maintains the maximum of all 2nd moment running avg. till now
#     147     torch.maximum(max_exp_avg_sqs[i], exp_avg_sq, out=max_exp_avg_sqs[i])
#
# KeyboardInterrupt:

# %%
torch.cuda.empty_cache()

# %%
# generate from the model
context = torch.tensor(encode('рак на горе свистнул'), dtype=torch.long, device=device).reshape(1,-1)
#print(context)
# context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=100)[0].tolist()))
# Out:
# рак на горе свистнульты, что важно размерентстве жизнально иРоссии описы, каковное еще стальтатев спосъемкуются в в в (ф
